# %% [markdown]
# <a href="https://colab.research.google.com/github/atsu8864/Graduation-Research/blob/main/%E5%8D%92%E6%A5%AD%E7%A0%94%E7%A9%B6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
item = ['ice_cream', 'nigirizushi', 'spring_roll']
ind = ['ind_i', 'ind_n', 'ind_s']
for i in range(3):
    files = glob.glob('/content/sample_data/new/' + item[i] + '/*')
    j = 1
    for file in files:
        if j > 120:
            break
        shutil.copyfile(file, '/content/sample_data/news/' + item[i] + '/' + str(j) + '.jpg')
        j += 1

# %%
import imghdr
import glob
files = glob.glob('/content/sample_data/news/*/*')
for file in files:
    if imghdr.what(file) !=  'jpeg':
        os.remove(file)
        print(file)

# %%
shutil.copyfile('/content/sample_data/dataset/ice_cream/000002.jpg', '/content/sample_data/dataset/ice_cream/000001.jpg')
# Out:
# '/content/sample_data/dataset/ice_cream/000001.jpg'

# %%
#pre_datasetからdatasetに画像データを戻す
for i in range(len(item)):
    files = glob.glob('/content/sample_data/pre_dataset/' + item[i] + '/*')
    false_files = glob.glob('/content/sample_data/pre_dataset/false_' + item[i] + '/*')
    for j in files:
        shutil.move(j, '/content/sample_data/ronbun/' + item[i])
    for j in false_files:
        shutil.move(j, '/content/sample_data/dataset/' + item[i])

# %% [markdown]
# #food101関係

# %%
#@title food_labelにないフォルダを削除
import glob
import shutil
import os
images = glob.glob('/content/food-101/images/*')
for image in images:
    _, dir = os.path.split(image)
    if not(food_labels.count(dir)):
        shutil.rmtree(image)

# %%
#@title food101の全てのクラスを取得
# food_labels = []
# with open('/content/drive/My Drive/Colaboratory/food_label.txt') as f:
#     for line in f:
#         line = line.replace("\n", "")
#         line = line.replace(" ", "_")
#         s = line.lower()
#         food_labels.append(s)

# %% [markdown]
# * エラー表
# * class_namesが間違っていないか
# * pathが間違っていないか
# * pathの構造は間違っていないか（/*/*なのに/*にしか画像がないなど）
# * decodeする拡張子は間違っていないか
# * 拡張子が間違っていないか
# * 拡張子がバラバラになっていないか

# %% [markdown]
# #次やること
# * usbにする必要はないからfood101で実行してみる
# * ある程度終わったらランキング学習の評価で評価してみる（nDCGなど）
# * pythonで適合度を入力するのは厳しいので、データをダウンロードしてから紙に適合度が低いのを書いて計算したほうが早いかも
# * 既存のモデルを使って比べてみる(ランキングsvmとかで)
# * 事前学習のデータは何枚くらいがいいか調べる
# * usbなどでコネクタのみの画像で学習したら、相対的に確率が低くなるから、確率80%で切るのではなく上から何枚かだけ正しいとすれば精度が出るかも。それも上から何枚がいいか調べる
# * 精度が高すぎるので、trainのデータのフォルダを変えて、数枚だけのフォルダを作って実行してみる。
# * 精度はテストデータに対してのみなので、nDCGで精度をみてみる
# * food_101の画像データをtestデータとしてwebから集めた数十枚の画像で学習した後、いったんtestデータで精度をとる。その後、webから数百枚集めて、f値が一番高い枚数まで（もう少し少ないほうがいいかも、ノイズを一番小さくしたい）で学習させて、testデータで精度を確かめる。
# * 96*96pxでどれくらいの精度が出るかやる
# * usbでもう一回やってみる。手動でスコアをつけて、nDCGで精度をみる
# * 3クラスだとaccが高すぎるから画像を集めたらaccがあがるかどうかはクラスを増やしてから確かめる
# * nDCGはクラスわけする必要がないから1クラスずつ学習させて、スコアが上がるかを確かめる
#   * 1クラス、3クラス、5クラスでやってどれくらい精度が落ちるのかを検証する。もし、あまり落ちなかったら複数クラスで行ったほうが速いと思うから、論文にかけそう。
#  * 1クラス学習させる時に、スコアが低い画像と高い画像の分類をさせるか、スコアが高い画像だけで学習させるかで、nDCGが上がるかを確かめる。
#  * 1クラスだけで学習させることは出来ないから、webから取ってきた時に各クラスの逆のクラス(not spring_rollなど)を作ってそこに入れて学習させたらできるかも
#  * 1クラスだけじゃなく分けたい画像とそれ以外の画像の2クラスで学習したらできる気がする
#  * 逆にスコアが低い画像だけを学習させて、そのモデルで評価が高い画像を抜き取るともう少しスコアがあがるかも
# * モデルの評価はクローラーでwebから集めた画像のnDCGをはかって、そのスコアとその画像をモデルを使って学習したスコアを比べて上がっているかどうかを見ればできるかも
#  * その時に、クローラーで集めた画像が上から順になっているかどうかを確かめる。集めた時に順番がバラバラだった場合は、正しくスコアが計算できないから。
#  * おそらく上から順に取ってきていると思う（Bingのランキング学習通りかな）
# * 今まで、datasetはaiが正しく判別できた画像のみを使ってたから、画像データを取り直したほうがいい
# * サンプル数の数によってスコアが変わるからどれくらいのサンプル数で元のスコアを超えられるかを調べる
# * food_datasetをtrain用とtest用に分ける
# * carrotだとスコア用の画像とtrainが同じものが入っているからfood101系統の画像を使って1クラス分類（trueとそれ以外みたいな）やtrueとfalseに分けて分類したりしてみる
# * nDCGは最後らへんのスコアが小さすぎる気がするから、ランキング学習の評価などでデータ全体を評価できそうな評価方法を探してみる
# * モデルをresnet50だけじゃなく、もう少し大きいモデルでもやって拡張性があるか確かめる
# * webデータセットを集める時は、上からx枚とかだと元の欲しい画像の枚数がxより少ない時に、欲しくない画像が絶対に含まれてしまうから、上からのパーセントで決めたほうがいいかも
#  * 論文だといろいろなクラスで、横軸に上からのパーセント、縦軸にnDCGかF値で（F値の方が良さそう）グラフを書いて、何%がいいとかを言えれば良さそう
# * F値が一番高いところまでのスコアを取ると高くなるかも
#  *　高くなった
# * pre_datasetに移すとdatasetが減っちゃうから50枚くらい他から集めたほうがいいかも
# * datasetにcarrotの10が少なすぎるから移動させる
# * 不正解画像と正解画像のクラスを作って、正解画像のみに振り分けるといい感じに分けられるかも。（卒研発表の時に使えそう）
# * true-falseをやると、falseの画像が少ないと、falseの画像に含まれなかったfalseの画像の種類がスコアが高くなってしまう。なので、true-falseをやる時はfalseの画像の種類が特定できて、ほとんどカバーできる時しかできないかも。
# * true-falseをやるんじゃなくて、falseに引っ掛かったらその画像を取り除いたほうがいいかも。
# * resnetとbitの近いが卒研発表の質問で出るかも

# %%
# !wget -P /tmp/ http://data.vision.ee.ethz.ch/cvl/food-101.tar.gz
# Out:
# --2020-12-10 02:51:39--  http://data.vision.ee.ethz.ch/cvl/food-101.tar.gz
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.162
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.162|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/food-101.tar.gz [following]
# --2020-12-10 02:51:40--  https://data.vision.ee.ethz.ch/cvl/food-101.tar.gz
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4996278331 (4.7G) [application/x-gzip]
# Saving to: ‘/tmp/food-101.tar.gz’
#
# food-101.tar.gz     100%[===================>]   4.65G  16.6MB/s    in 4m 26s
#
# 2020-12-10 02:56:06 (17.9 MB/s) - ‘/tmp/food-101.tar.gz’ saved [4996278331/4996278331]

# %%
# !tar -xvzf /tmp/food-101.tar.gz

# %%
# !zip ./nigirizusi.zip ./sushi/*.jpg

# %%
files.download('./nigirizusi.zip')

# %%
os.chdir('../')

# %%
import os
os.chdir('./food')

# %%
try:
    shutil.rmtree('/content/sample_data/web')
except:
    pass
shutil.copytree('/content/drive/MyDrive/Colaboratory/dataset/web', '/content/sample_data/web')
# Out:
# '/content/sample_data/web'

# %%
shutil.rmtree('/content/smaple_data')

# %%
#@title #downloaded stl10_data


from __future__ import print_function

import sys
import os, sys, tarfile, errno
import numpy as np
import matplotlib.pyplot as plt
    
if sys.version_info >= (3, 0, 0):
    import urllib.request as urllib # ugly but works
else:
    import urllib

try:
    from imageio import imsave
except:
    from scipy.misc import imsave

print(sys.version_info) 

# image shape
HEIGHT = 96
WIDTH = 96
DEPTH = 3

# size of a single image in bytes
SIZE = HEIGHT * WIDTH * DEPTH

# path to the directory with the data
DATA_DIR = './data'

# url of the binary data
DATA_URL = 'http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz'

# path to the binary train file with image data
TRAIN_DATA_PATH = './data/stl10_binary/train_X.bin'

# path to the binary train file with labels
TRAIN_LABEL_PATH = './data/stl10_binary/train_y.bin'

TEST_DATA_PATH = './data/stl10_binary/test_X.bin'
TEST_LABEL_PATH = './data/stl10_binary/test_y.bin'
def read_labels(path_to_labels):
    """
    :param path_to_labels: path to the binary file containing labels from the STL-10 dataset
    :return: an array containing the labels
    """
    with open(path_to_labels, 'rb') as f:
        labels = np.fromfile(f, dtype=np.uint8)
        return labels


def read_all_images(path_to_data):
    """
    :param path_to_data: the file containing the binary images from the STL-10 dataset
    :return: an array containing all the images
    """

    with open(path_to_data, 'rb') as f:
        # read whole file in uint8 chunks
        everything = np.fromfile(f, dtype=np.uint8)

        # We force the data into 3x96x96 chunks, since the
        # images are stored in "column-major order", meaning
        # that "the first 96*96 values are the red channel,
        # the next 96*96 are green, and the last are blue."
        # The -1 is since the size of the pictures depends
        # on the input file, and this way numpy determines
        # the size on its own.

        images = np.reshape(everything, (-1, 3, 96, 96))

        # Now transpose the images into a standard image format
        # readable by, for example, matplotlib.imshow
        # You might want to comment this line or reverse the shuffle
        # if you will use a learning algorithm like CNN, since they like
        # their channels separated.
        images = np.transpose(images, (0, 3, 2, 1))
        return images


def read_single_image(image_file):
    """
    CAREFUL! - this method uses a file as input instead of the path - so the
    position of the reader will be remembered outside of context of this method.
    :param image_file: the open file containing the images
    :return: a single image
    """
    # read a single image, count determines the number of uint8's to read
    image = np.fromfile(image_file, dtype=np.uint8, count=SIZE)
    # force into image matrix
    image = np.reshape(image, (3, 96, 96))
    # transpose to standard format
    # You might want to comment this line or reverse the shuffle
    # if you will use a learning algorithm like CNN, since they like
    # their channels separated.
    image = np.transpose(image, (2, 1, 0))
    return image


def plot_image(image):
    """
    :param image: the image to be plotted in a 3-D matrix format
    :return: None
    """
    plt.imshow(image)
    plt.show()

def save_image(image, name):
    imsave("%s.png" % name, image, format="png")

def download_and_extract():
    """
    Download and extract the STL-10 dataset
    :return: None
    """
    dest_directory = DATA_DIR
    if not os.path.exists(dest_directory):
        os.makedirs(dest_directory)
    filename = DATA_URL.split('/')[-1]
    filepath = os.path.join(dest_directory, filename)
    if not os.path.exists(filepath):
        def _progress(count, block_size, total_size):
            sys.stdout.write('\rDownloading %s %.2f%%' % (filename,
                float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
        filepath, _ = urllib.urlretrieve(DATA_URL, filepath, reporthook=_progress)
        print('Downloaded', filename)
        tarfile.open(filepath, 'r:gz').extractall(dest_directory)

def save_images(images, labels, a):
    print("Saving images to disk")
    i = 0
    for image in images:
        label = labels[i]
        directory = './img_' + a + '/' + str(label) + '/'
        try:
            os.makedirs(directory, exist_ok=True)
        except OSError as exc:
            if exc.errno == errno.EEXIST:
                pass
        filename = directory + str(i)
        #print(filename)
        save_image(image, filename)
        i = i+1
    
if __name__ == "__main__":
    # download data if needed
    download_and_extract()

    # test to check if the image is read correctly
    with open(TRAIN_DATA_PATH) as f:
        image = read_single_image(f)
        plot_image(image)

    # test to check if the whole dataset is read correctly
    images = read_all_images(TRAIN_DATA_PATH)
    print(images.shape)

    labels = read_labels(TRAIN_LABEL_PATH)
    print(labels.shape)

    save_images(images, labels, 'train')


    images = read_all_images(TEST_DATA_PATH)
    print(images.shape)

    labels = read_labels(TEST_LABEL_PATH)
    print(labels.shape)

    # save images to disk
    save_images(images, labels, 'test')

# %% [markdown]
# #scores

# %%
carrot_score = [('/content/sample_data/dataset/carrot/000001.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000002.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000003.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000004.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000005.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000006.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000007.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000008.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000009.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000010.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000011.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000012.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000013.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000014.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000015.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000016.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000017.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000018.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000019.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000020.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000021.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000022.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000023.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000024.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000025.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000026.jpg', '7'),
 ('/content/sample_data/dataset/carrot/000027.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000028.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000029.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000030.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000031.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000032.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000033.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000034.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000035.jpg', '4'),
 ('/content/sample_data/dataset/carrot/000036.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000037.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000038.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000039.jpg', '2'),
 ('/content/sample_data/dataset/carrot/000040.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000041.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000042.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000043.jpg', '3'),
 ('/content/sample_data/dataset/carrot/000044.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000045.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000046.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000047.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000048.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000049.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000050.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000051.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000052.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000053.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000054.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000055.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000056.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000057.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000058.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000059.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000060.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000061.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000062.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000063.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000064.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000065.jpg', '5'),
 ('/content/sample_data/dataset/carrot/000066.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000067.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000068.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000069.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000070.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000071.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000072.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000073.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000074.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000075.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000076.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000077.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000078.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000079.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000080.jpg', '7'),
 ('/content/sample_data/dataset/carrot/000081.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000082.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000083.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000084.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000085.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000086.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000087.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000088.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000089.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000090.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000091.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000092.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000093.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000094.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000095.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000096.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000097.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000098.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000099.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000100.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000101.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000102.jpg', '6'),
 ('/content/sample_data/dataset/carrot/000103.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000104.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000105.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000106.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000107.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000108.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000109.jpg', '7'),
 ('/content/sample_data/dataset/carrot/000110.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000111.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000112.jpg', '10'),
 ('/content/sample_data/dataset/carrot/000113.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000114.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000115.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000116.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000117.jpg', '0'),
 ('/content/sample_data/dataset/carrot/000118.jpg', '0'),
 ('/content/sample_data/dataset/carrot/
jpg', '10'),
 ('/content/sample_data/dataset/spring_roll/000205.jpg', '0')]

# %%
ice_cream_score = {k: v for (k, v) in ice_cream_score}
nigirizushi_score = {k: v for (k, v) in nigirizushi_score}
spring_roll_score = {k: v for (k, v) in spring_roll_score}
carrot_score = {k: v for (k, v) in carrot_score}

# %% [markdown]
# #downloaded sample_food and creat pre_dataset

# %%
import shutil
import os
try:
    shutil.rmtree('/content/sample_data/dataset')
except:
    pass
os.mkdir('/content/sample_data/dataset')
os.chdir('/content/sample_data/dataset')
shutil.copyfile('/content/drive/MyDrive/Colaboratory/dataset/true_dataset3.zip', '/content/sample_data/dataset/true_dataset3.zip')
# Out:
# '/content/sample_data/dataset/true_dataset3.zip'

# %%
# !unzip /content/sample_data/dataset/true_dataset3.zip
# Out:
# Archive:  /content/sample_data/dataset/true_dataset3.zip
#   inflating: carrot/000001.jpg
#   inflating: carrot/000004.jpg
#   inflating: carrot/000005.jpg
#   inflating: carrot/000008.jpg
#   inflating: carrot/000009.jpg
#   inflating: carrot/000019.jpg
#   inflating: carrot/000020.jpg
#   inflating: carrot/000023.jpg
#   inflating: carrot/000025.jpg
#   inflating: carrot/000026.jpg
#   inflating: carrot/000027.jpg
#   inflating: carrot/000029.jpg
#   inflating: carrot/000033.jpg
#   inflating: carrot/000040.jpg
#   inflating: carrot/000045.jpg
#   inflating: carrot/000058.jpg
#   inflating: carrot/000059.jpg
#   inflating: carrot/000062.jpg
#   inflating: carrot/000063.jpg
#   inflating: carrot/000064.jpg
#   inflating: carrot/000068.jpg
#   inflating: carrot/000071.jpg
#   inflating: carrot/000075.jpg
#   inflating: carrot/000078.jpg
#   inflating: carrot/000082.jpg
#   inflating: carrot/000084.jpg
#   inflating: carrot/000086.jpg
#   inflating: carrot/000087.jpg
# ...

# %%
import shutil
import os
os.chdir('/content/sample_data')
shutil.copyfile('/content/drive/MyDrive/Colaboratory/dataset/ronbun.zip', '/content/sample_data/ronbun.zip')
# Out:
# '/content/sample_data/ronbun.zip'

# %%
# !unzip /content/sample_data/ronbun.zip
# Out:
# Archive:  /content/sample_data/ronbun.zip
#    creating: ronbun/
#   inflating: __MACOSX/._ronbun
#    creating: ronbun/ice_cream/
#   inflating: ronbun/.DS_Store
#   inflating: __MACOSX/ronbun/._.DS_Store
#    creating: ronbun/spring_roll/
#    creating: ronbun/nigirizushi/
#    creating: ronbun/carrot/
#   inflating: __MACOSX/ronbun/._carrot
#   inflating: ronbun/ice_cream/000146.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000146.jpg
#   inflating: ronbun/ice_cream/000218.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000218.jpg
#   inflating: ronbun/ice_cream/000184.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000184.jpg
#   inflating: ronbun/ice_cream/000147.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000147.jpg
#   inflating: ronbun/ice_cream/000233.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000233.jpg
#   inflating: ronbun/ice_cream/000031.jpg
#   inflating: __MACOSX/ronbun/ice_cream/._000031.jpg
#   inflating: ronbun/ice_cream/000018.jpg
# ...

# %%
#@title 拡張子を診断
# import imghdr
# import glob
# files = glob.glob('/content/sample_data/carrot/*/*')
# for file in files:
#     filetype = imghdr.what(file)
#     if filetype != 'jpeg':
#         print(file)
#         os.remove(file)

# %%
#@title #import
from IPython.display import display
import math
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

import pandas as pd
import matplotlib.pyplot as plt

import time
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import numpy as np
import os
import pathlib
import shutil
import glob
from natsort import natsorted

#@title label
tf_flowers_labels = ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']
stl10_labels = ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
usb_labels = ['usb-c', 'lightning', 'micro2-b']
carrot_labels = ['true_carrot', 'false_carrot']
food_labels = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot']
false_labels = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot', 'false_ice_cream', 'false_nigirizushi', 'false_spring_roll', 'false_carrot']
#food_labels = ['Japanese_pear', 'avocado', 'carrot', 'eggs', 'green_pepper', 'lemon', 'orange', 'oyster', 'peach', 'strawberry']
#food_labels = ['apple_pie', 'gyoza', 'pizza', 'sushi', 'takoyaki']
#@title download the model
model_url = "https://tfhub.dev/google/bit/m-r50x1/1"

#model_url = "https://tfhub.dev/google/bit/m-r50x3/1"
module = hub.KerasLayer(model_url)
#pre_datasetからdatasetに画像データを戻す
for i in range(len(item)):
    files = glob.glob('/content/sample_data/pre_dataset/' + item[i] + '/*')
    false_files = glob.glob('/content/sample_data/pre_dataset/false_' + item[i] + '/*')
    for j in files:
        shutil.move(j, '/content/sample_data/ronbun/' + item[i])
    for j in false_files:
        shutil.move(j, '/content/sample_data/dataset/' + item[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c0c04e4dab51> in <module>()
#      36 module = hub.KerasLayer(model_url)
#      37 #pre_datasetからdatasetに画像データを戻す
# ---> 38 for i in range(len(item)):
#      39     files = glob.glob('/content/sample_data/pre_dataset/' + item[i] + '/*')
#      40     false_files = glob.glob('/content/sample_data/pre_dataset/false_' + item[i] + '/*')
#
# NameError: name 'item' is not defined

# %%
#@title label
tf_flowers_labels = ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']
stl10_labels = ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
usb_labels = ['usb-c', 'lightning', 'micro2-b']
carrot_labels = ['true_carrot', 'false_carrot']
food_labels = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot']
false_labels = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot', 'false_ice_cream', 'false_nigirizushi', 'false_spring_roll', 'false_carrot']
#food_labels = ['Japanese_pear', 'avocado', 'carrot', 'eggs', 'green_pepper', 'lemon', 'orange', 'oyster', 'peach', 'strawberry']
#food_labels = ['apple_pie', 'gyoza', 'pizza', 'sushi', 'takoyaki']
#@title download the model
model_url = "https://tfhub.dev/google/bit/m-r50x1/1"

#model_url = "https://tfhub.dev/google/bit/m-r50x3/1"
module = hub.KerasLayer(model_url)
#@title download the model
model_url = "https://tfhub.dev/google/bit/m-r50x1/1"

#model_url = "https://tfhub.dev/google/bit/m-r50x3/1"
module = hub.KerasLayer(model_url)

# %%
#pre_datasetからdatasetに画像データを戻す
for i in range(len(item)):
    files = glob.glob('/content/sample_data/pre_dataset/' + item[i] + '/*')
    false_files = glob.glob('/content/sample_data/pre_dataset/false_' + item[i] + '/*')
    for j in files:
        shutil.move(j, '/content/sample_data/ronbun/' + item[i])
    for j in false_files:
        shutil.move(j, '/content/sample_data/dataset/' + item[i])

# %%
# import glob#carrotの枚数を他と同じ200枚にする
# os.rename('/content/sample_data/dataset/carrot', '/content/sample_data/dataset/t_carrot')
# shutil.move('/content/sample_data/dataset/t_carrot', '/content/sample_data/')
# os.mkdir('/content/sample_data/dataset/carrot')
# files = glob.glob('/content/sample_data/t_carrot/*.jpg')
# j = 1
# for i in files:
#     shutil.copy(i, '/content/sample_data/dataset/carrot/')
#     if j >= 200:
#         break
#     j += 1

# %%
try:
    shutil.rmtree('/content/sample_data/pre_dataset')
    
except:
    pass
item = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot']
os.mkdir('/content/sample_data/pre_dataset')
for i in range(len(item)):
    os.mkdir('/content/sample_data/pre_dataset/' + item[i])
    os.mkdir('/content/sample_data/pre_dataset/false_' + item[i])
import glob
import random
for i in range(len(item)):
    files = glob.glob('/content/sample_data/ronbun/' + item[i] + '/*')
    j = 1
    files = random.sample(files, 1)
    for file in files:
        score_name = item[i] + '_score'
        base = os.path.basename(file)
        file_name = '/content/sample_data/dataset/' + item[i] + '/' + base
        shutil.move(file, '/content/sample_data/pre_dataset/' + item[i] + '/' + base)
#スコアが0なのを取る
import glob
for i in range(len(item)):
    files = glob.glob('/content/sample_data/dataset/' + item[i] + '/*')
    j = 1
    for file in files:
        score_name = item[i] + '_score'
        base = os.path.basename(file)
        file_name = '/content/sample_data/dataset/' + item[i] + '/' + base
        if eval(score_name)[file_name] == '0':
            shutil.move(file, '/content/sample_data/pre_dataset/false_' + item[i] + '/' + base)
        else:
            continue
        if j >= 1:
            break
        j += 1
files = glob.glob('/content/sample_data/dataset/ice_cream/*')
j = 1
z = 0
f = 0
g = 0
print(len(files))
for file in files:
    score_name = 'carrot_score'
    base = os.path.basename(file)
    file_name = '/content/sample_data/dataset/carrot/' + base
    if eval(score_name)[file_name] == '10':
        z += 1
    elif eval(score_name)[file_name] == '9':
        z += 1
    elif eval(score_name)[file_name] == '8':
        z += 1
    elif eval(score_name)[file_name] == '7':
        z += 1
    elif eval(score_name)[file_name] == '6':
        z += 1
    elif eval(score_name)[file_name] == '0':
        f += 1
    else:
        g += 1
print('6~10 : ', z)
print('0 : ', f)
print(g)
item = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot']
os.mkdir('/content/sample_data/pre_dataset')
for i in range(len(item)):
    os.mkdir('/content/sample_data/pre_dataset/' + item[i])
    os.mkdir('/content/sample_data/pre_dataset/false_' + item[i])
import glob
import random
for i in range(len(item)):
    files = glob.glob('/content/sample_data/ronbun/' + item[i] + '/*')
    j = 1
    files = random.sample(files, 1)
    for file in files:
        score_name = item[i] + '_score'
        base = os.path.basename(file)
        file_name = '/content/sample_data/dataset/' + item[i] + '/' + base
        shutil.move(file, '/content/sample_data/pre_dataset/' + item[i] + '/' + base)
#スコアが0なのを取る
import glob
for i in range(len(item)):
    files = glob.glob('/content/sample_data/dataset/' + item[i] + '/*')
    j = 1
    for file in files:
        score_name = item[i] + '_score'
        base = os.path.basename(file)
        file_name = '/content/sample_data/dataset/' + item[i] + '/' + base
        if eval(score_name)[file_name] == '0':
            shutil.move(file, '/content/sample_data/pre_dataset/false_' + item[i] + '/' + base)
        else:
            continue
        if j >= 1:
            break
        j += 1
#一般
#@title pathを指定してdatasetを作る
data_dir = pathlib.Path('/content/sample_data/pre_dataset')
data_dir_val = pathlib.Path('/content/sample_data/dataset')


IMG_HEIGHT = 96
IMG_WIDTH = 96

CLASS_NAMES = false_labels  # from plotting helper functions above
NUM_CLASSES = len(CLASS_NAMES)
num_examples = len(list(data_dir.glob('*/*.jpg')))

def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  
  return tf.where(parts[-2] == CLASS_NAMES)[0][0]

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  return img  

def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  features = {'image': img, 'label': label}
  return features

list_ds_train = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'))
ds = list_ds_train.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)

num_examples
ds_train = ds


DATASET_NUM_TRAIN_EXAMPLES = num_examples
#@title BiTのheadを付け替えて0で初期化
class MyBiTModel(tf.keras.Model):

  def __init__(self, num_classes, module):
    super().__init__()

    self.num_classes = num_classes
    self.head = tf.keras.layers.Dense(num_classes, kernel_initializer='zeros')
    self.bit_model = module

  def call(self, images):
    bit_embedding = self.bit_model(images)
    return self.head(bit_embedding)
  
model = MyBiTModel(num_classes=NUM_CLASSES, module = module)

#@title image_sizeとdataset_sizeによってスケジュール（epoch）とresizeの値を変更
IMAGE_SIZE = "<96x96 px"
DATASET_SIZE = "<20k examples"

if IMAGE_SIZE == "=<96x96 px":
  RESIZE_TO = 160
  CROP_TO = 128
else:
  RESIZE_TO = 512
  CROP_TO = 480

if DATASET_SIZE == "<20k examples":
  SCHEDULE_LENGTH = 500
  SCHEDULE_BOUNDARIES = [200, 300, 400]
elif DATASET_SIZE == "20k-500k examples":
  SCHEDULE_LENGTH = 100000
  SCHEDULE_BOUNDARIES = [3000, 6000, 9000]
else:
  SCHEDULE_LENGTH = 20000
  SCHEDULE_BOUNDARIES = [6000, 12000, 18000]
#@title batch_sizeを指定して各データセットのpipelineを作成
BATCH_SIZE = 64
SCHEDULE_LENGTH = SCHEDULE_LENGTH * 512 / BATCH_SIZE

STEPS_PER_EPOCH = 10

def cast_to_tuple(features):
  return (features['image'], features['label'])

def preprocess_train(features):
  features['image'] = tf.image.random_flip_left_right(features['image'])
  features['image'] = tf.image.resize(features['image'], [RESIZE_TO, RESIZE_TO])
  features['image'] = tf.image.random_crop(features['image'], [CROP_TO, CROP_TO, 3])
  features['image'] = tf.cast(features['image'], tf.float32) / 255.0
  return features

def preprocess_test(features):
  features['image'] = tf.image.resize(features['image'], [RESIZE_TO, RESIZE_TO])
  features['image'] = tf.cast(features['image'], tf.float32) / 255.0
  return features



pipeline_train = (ds_train
                 .shuffle(10000)
                 .repeat(int(SCHEDULE_LENGTH * BATCH_SIZE / DATASET_NUM_TRAIN_EXAMPLES * STEPS_PER_EPOCH) + 1 + 50)
                 .map(preprocess_train, num_parallel_calls=8)
                 .batch(BATCH_SIZE)
                 .map(cast_to_tuple)
                 .prefetch(2))

# pipeline_val = (ds_val
#                  .map(preprocess_test, num_parallel_calls=1)
#                  .map(cast_to_tuple)
#                  .batch(BATCH_SIZE)
#                  .prefetch(2))
# pipeline_test = (ds_test
#                  .map(preprocess_test, num_parallel_calls=1)
#                  .map(cast_to_tuple)
#                  .batch(BATCH_SIZE))
#@title スケジュールを決定
lr = 0.003 * BATCH_SIZE / 512

lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(boundaries=SCHEDULE_BOUNDARIES,
                                                                  values=[lr, lr*0.1, lr*0.001, lr*0.0001])
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#@title epoch数を指定してコンパイル
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

NUM_EPOCH = 5

history = model.fit(
    pipeline_train,
    batch_size=BATCH_SIZE,
    steps_per_epoch=STEPS_PER_EPOCH,
    epochs=NUM_EPOCH#, #int(SCHEDULE_LENGTH/STEPS_PER_EPOCH),
    #validation_data=pipeline_val
)
print("Evaluate")
# result = model.evaluate(pipeline_val)
# dict(zip(model.metrics_names, result))
export_module_dir = "/content/drive/My Drive/Colaboratory/save_model"
tf.saved_model.save(model, export_module_dir)
saved_module = hub.KerasLayer(export_module_dir, trainable=True)
#@title plot the wrong image 
# Show the MAX_PREDS highest scoring labels:
MAX_PREDS = 5
# Do not show labels with lower score than this:
MIN_SCORE = 0.8 

def show_preds(logits, image, correct_usb_label=None, tf_usb_logits=False):

  if len(logits.shape) > 1:
    logits = tf.reshape(logits, [-1])

  fig, axes = plt.subplots(1, 2, figsize=(7, 1), squeeze=False)

  ax1, ax2 = axes[0]

  ax1.axis('off')
  ax1.imshow(image)
  if correct_usb_label is not None:
    ax1.set_title(usb_labels[correct_usb_label])
  classes = []
  scores = []
  logits_max = np.max(logits)
  softmax_denominator = np.sum(np.exp(logits - logits_max))
  for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
    score = 1.0/(1.0 + np.exp(-logits[j]))
    if score < MIN_SCORE:
        pass 
        #break
    if not tf_usb_logits:
      # predicting in imagenet label space
      classes.append(imagenet_int_to_str[j])
    else:
      # predicting in tf_usb label space
      classes.append(usb_labels[j])
    scores.append(np.exp(logits[j] - logits_max)/softmax_denominator*100)
  if classes[0] != usb_labels[correct_usb_label]:
    print(score)
    ax2.barh(np.arange(len(scores)) + 0.1, scores)
    ax2.set_xlim(0, 100)
    ax2.set_yticks(np.arange(len(scores)))
    ax2.yaxis.set_ticks_position('right')
    ax2.set_yticklabels(classes, rotation=0, fontsize=14)
    ax2.invert_xaxis()
    ax2.invert_yaxis()
    ax2.set_xlabel('Prediction probabilities', fontsize=11)
#@title plot all image
# Show the MAX_PREDS highest scoring labels:
MAX_PREDS = 5
# Do not show labels with lower score than this:
MIN_SCORE = 0.8 

def show_preds(logits, image, correct_food_label=None, tf_food_logits=False):

  if len(logits.shape) > 1:
    logits = tf.reshape(logits, [-1])

  fig, axes = plt.subplots(1, 2, figsize=(7, 1), squeeze=False)

  ax1, ax2 = axes[0]

  ax1.axis('off')
  ax1.imshow(image)
  if correct_food_label is not None:
    ax1.set_title(food_labels[correct_food_label])
  classes = []
  scores = []
  logits_max = np.max(logits)
  softmax_denominator = np.sum(np.exp(logits - logits_max))
  for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
    score = 1.0/(1.0 + np.exp(-logits[j]))
    if score < MIN_SCORE:
        pass 
        #break
    if not tf_usb_logits:
      # predicting in imagenet label space
      classes.append(imagenet_int_to_str[j])
    else:
      # predicting in tf_usb label space
      classes.append(food_labels[j])
    scores.append(np.exp(logits[j] - logits_max)/softmax_denominator*100)
  ax2.barh(np.arange(len(scores)) + 0.1, scores)
  ax2.set_xlim(0, 100)
  ax2.set_yticks(np.arange(len(scores)))
  ax2.yaxis.set_ticks_position('right')

  ax2.set_yticklabels(classes, rotation=0, fontsize=14)
  ax2.invert_xaxis()
  ax2.invert_yaxis()
  ax2.set_xlabel('Prediction probabilities', fontsize=11)
def preprocess_image(image):
  image = np.array(image)
  # reshape into shape [batch_size, height, width, num_channels]
  img_reshaped = tf.reshape(image, [1, image.shape[0], image.shape[1], image.shape[2]])
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  image = tf.image.convert_image_dtype(img_reshaped, tf.float32)  
  return image

def load_image_from_url(url):
  """Returns an image with shape [1, height, width, num_channels]."""
  response = requests.get(url)
  image = Image.open(BytesIO(response.content))
  image = preprocess_image(image)
  return image
#lanking images
import shutil
#image_paths = glob.glob('/content/sample_data/carrot_score/*')
image_paths = glob.glob('/content/sample_data/dataset/*/*')

spring_roll_lank = []
nigirizushi_lank = []
ice_cream_lank = []
takoyaki_lank = []
different = []
carrot_lank = []#carrotはtrue-falseをスコアとする
i = 0

for image_path in image_paths:
    dir_name = os.path.dirname(image_path)
    _, dir_name = os.path.split(dir_name)
    dir_path = os.path.dirname(image_path)

    if dir_name == 'different_images' or dir_name == 'improper_images':
        break
    try:
        image = Image.open(image_path).convert('RGB')
    except:
        print(image_path)
    im = image
    image = preprocess_image(image)
    image = tf.image.resize(image, [CROP_TO, CROP_TO])

    logits = saved_module(image)
    tf_usb_logits=True
    image = image[0]


    if len(logits.shape) > 1:
        logits = tf.reshape(logits, [-1])

    correct_label = food_labels.index(dir_name)

    MAX_PREDS = 8
    MAX_LABEL = None
    classes = []
    scores = []
    CORRECT_SCORE = 0.0

    # for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
    #     if j == 0:
    #         true_score = 1.0/(1.0 + np.exp(-logits[j]))
    #     elif j == 1:
    #         false_score = 1.0/(1.0 + np.exp(-logits[j]))
    # score = true_score - false_score
    # t = (image_path, score)
    # carrot_lank.append(t)
    """
    #複数のtrue_false
    print(image_path)
    for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
        score = 1.0/(1.0 + np.exp(-logits[j]))
        if j == 0:
            true_ice = score
        elif j == 1:
            true_nigirizushi = score
        elif j == 2:
            true_spring = score
            print(score)

        elif j == 3:
            true_carrot = score        
        elif j == 4:
            false_ice = score
        elif j == 5:
            false_nigirizushi = score
        elif j == 6:
            false_spring = score
            print(score)
        elif j == 7:
            false_carrot = score  
    if dir_name == 'ice_cream':
        score = true_ice - false_ice
        CORRECT_SCORE = score
        t = (image_path, CORRECT_SCORE)
        ice_cream_lank.append(t)
    elif dir_name == 'nigirizushi':
        score = true_nigirizushi - false_nigirizushi
        CORRECT_SCORE = score
        t = (image_path, CORRECT_SCORE)
        nigirizushi_lank.append(t)
    elif dir_name == 'spring_roll':
        score = true_spring - false_spring
        CORRECT_SCORE = score
        t = (image_path, CORRECT_SCORE)
        spring_roll_lank.append(t)
    elif dir_name == 'carrot':
        score = true_carrot - false_carrot
        CORRECT_SCORE = score
        t = (image_path, CORRECT_SCORE)
        carrot_lank.append(t)
    #"""
    #"""
    #複数
    # if i % 2 == 0:
    #     print(food_labels)
    # i +=1
    # print(image_path)
    # print(correct_label)
    for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
        score = 1.0/(1.0 + np.exp(-logits[j]))
        # print(str(j) + ' : ' + str(score))
        if j == correct_label:
            CORRECT_SCORE = score
            t = (image_path, CORRECT_SCORE)
            if dir_name == 'spring_roll':
                spring_roll_lank.append(t)
            elif dir_name == 'nigirizushi':
                nigirizushi_lank.append(t)
            elif dir_name == 'ice_cream':
                ice_cream_lank.append(t)
            elif dir_name == 'carrot':
                carrot_lank.append(t)
    #"""
carrot_lank.sort(reverse=True, key=lambda x : x[1])
spring_roll_lank.sort(reverse=True, key=lambda x : x[1])
nigirizushi_lank.sort(reverse=True, key=lambda x : x[1])
ice_cream_lank.sort(reverse=True, key=lambda x : x[1])
ice_cream_lank

#重複検索
# for i in range(len(item_lank)):
#     old_score = 0
#     old_path = ''
#     s  = 0
#     for j in eval(item_lank[i]):
#         new_path, new_score = j
#         if old_score == new_score:
#             s += 1
#             if old_path == '':
#                 print(new_path + '  :  ' +  str(new_score))
#             else:
#                 print(old_path + '  :  ' + str(old_score))
#                 print(new_path + '  :  ' +  str(new_score))
#             new_path = ''
#         old_path = new_path
#         old_score = new_score

#     print(s)
#pathとスコア（手動）のタプルを作成
ice_cream = []
nigirizushi = []
spring_roll = []
carrot = []
def pa(path):#carrot_scoreのpathを'/content/sample_data/true_dataset2/true_carrot/----.jpg'から'/content/sample_data/carrot_score/-----.jpg'に変える
    remain, base = os.path.split(path)
    c, _ = os.path.split(remain)
    e, _ = os.path.split(c)
    p = e + '/dataset/carrot/' + base
    return p

def retrieve(x):
    path, score = x
    a = os.path.basename(path)
    a, b = os.path.splitext(a)
    a = int(a)
    return a
#辞書を使う
def score(x, y):
    for c in x:
        s = ''
        if y == 'ice_cream':
            path, lank = c
            score = ice_cream_score[path]
            t = (path, score)
            ice_cream.append(t)
        elif y == 'nigirizushi':
            path, lank = c
            score = nigirizushi_score[path]
            t = (path, score)
            nigirizushi.append(t)
        elif y == 'spring_roll':
            path, lank = c
            score = spring_roll_score[path]
            t = (path, score)
            spring_roll.append(t)
        elif y == 'carrot':
            path, lank = c
            path = pa(path)
            score = carrot_score[path]
            t = (path, score)
            carrot.append(t)
# def score(x, y):
#     for c in x:
#         a = retrieve(c)
#         s = ''
#         if y == 'ice_cream':
#             p, s = ice_cream_score[a]
#             path, _ = c
#             t = (path, s)
#             ice_cream.append(t)
#         elif y == 'nigirizushi':
#             p, s = nigirizushi_score[a]
#             path, _ = c
#             t = (path, s)
#             nigirizushi.append(t)
#         elif y == 'spring_roll':
#             p, s = spring_roll_score[a]
#             path, _ = c
#             t = (path, s)
#             spring_roll.append(t)
score(ice_cream_lank, 'ice_cream')
score(nigirizushi_lank, 'nigirizushi')
score(spring_roll_lank, 'spring_roll')
score(carrot_lank, 'carrot')
#calculate the score FUNCTION

item_score = ['ice_cream_score', 'nigirizushi_score', 'spring_roll_score', 'carrot_score']
item = ['ice_cream', 'nigirizushi', 'spring_roll', 'carrot']
item_lank = ['ice_cream_lank', 'nigirizushi_lank', 'spring_roll_lank', 'carrot_lank']
#precision,recall,f_scoreを算出
def precision(x, n):
    tp = 0
    for path,score in x:
        score = int(score)
        if score >= 6:
            tp += 1
    precision = tp / n
    return precision

def recall(x, n):
    tp = 0
    like = 0
    for i in x:
        path, score = i
        score = int(score)
        if score >= 6:
            like += 1
    for i in range(n):
        path, score = x[i]
        score = int(score)
        if score >= 6:
            tp += 1       
    recall = tp / like
    return recall

def f(x, n):
    pre = precision(x, n)
    rec = recall(x, n)
    f = 2 * rec * pre / (rec + pre)
    answer = {'precision' : pre, 'recall' : rec , 'F1' : f}
    return answer

    
#f_scoreの最大を抽出
def fmax(x):
    max_f = 0
    ind_f = 0
    for i in range(1, len(x)+1):
        d = f(x, i)
        if max_f < d['F1']:
            max_f = d['F1']
            ind_f = i
    answer = {'F1' : (max_f, ind_f)}
    return answer



#手動でのスコア
#同じデータセットの場合は変わらない
max_score_list = []
def count(a=[]):
    score = [s for p, s in a]
    return score
def dcg_score(a={}, fm=-1):    
    # if fm == -1:#辞書をリストに変換
    #     a = list(a.items())
    if fm != 1:
        a = count(a)
    t0 = [0 for i in range(a.count('0'))]
    t1 = [1 for i in range(a.count('1'))]
    t2 = [2 for i in range(a.count('2'))]
    t3 = [3 for i in range(a.count('3'))]
    t4 = [4 for i in range(a.count('4'))]
    t5 = [5 for i in range(a.count('5'))]
    t6 = [6 for i in range(a.count('6'))]
    t7 = [7 for i in range(a.count('7'))]
    t8 = [8 for i in range(a.count('8'))]
    t9 = [9 for i in range(a.count('9'))]
    t10 = [10 for i in range(a.count('10'))]

    t = t0 + t1 + t2 + t3 + t4 + t5 + t6 + t7 + t8 + t9 + t10
    t.sort(reverse=True)
    print(len(t))
    i = 1
    dcg = 0
    for score in t:
        if i == 1:
            dcg += score
        else:
            dcg += score/math.log(i)
        i += 1

    if fm != -1:
        return dcg
    else:
        max_score_list.append(dcg)
        


#aiのスコア
ai_score_list = []

#スコアの添字を抽出
def retrieve(x):
    path, score = x
    a = os.path.basename(path)
    a, b = a.split('_')
    a = int(a)
    return a

def ai_score(x, fm = -1):
    scores = []

    try: #元のランキング学習のスコアを確かめたい時に辞書型から変換させる
        x = list(x.items())
    except:
        pass
    dcg = 0
    i = 1
    for c in x:
        if fm != -1:
            if i == fm: # ice_creamのf_scoreの最大値
                break
        _, s = c
        if i == 1:
            dcg += int(s)
            scores.append(s)
        else:
            dcg += int(s)/math.log(i)
            scores.append(s)
            
        i += 1
    print(i)
    if fm != -1:
        return (dcg, scores)
    else:
        ai_score_list.append(dcg)


#f_scoreが最大の所でスコアを出す
fmax_score_list = []

def fmax_score():
    for i in item:
        a = fmax(eval(i))
        score, ind = a['F1']
        ai, scores = ai_score(eval(i), ind)
        dcg = dcg_score(scores, 1)
        fmax_score_list.append(ai/dcg)
        print(i, ind, '割合', ind/len(eval(i)))
#スコアを計算して出力
#最高（手動）
ice_cream_dcg = dcg_score(ice_cream)
nigirizushi_dcg = dcg_score(nigirizushi)
spring_roll_dcg = dcg_score(spring_roll)
carrot_dcg = dcg_score(carrot)

# # #ai
# # sort_lank(ice_cream_score)
# # sort_lank(nigirizushi_score)
# # sort_lank(spring_roll_score)

ai_score(ice_cream)
ai_score(nigirizushi)
ai_score(spring_roll)
ai_score(carrot)

fmax_score()
score = []
for m, a in zip(max_score_list, ai_score_list):
    score.append(a/m)
print(max_score_list)
print(ai_score_list)
print(score)
print(fmax_score_list)
s_score = []
for s in score:
    s_score.append(str(s) + ', ')
with open('/content/drive/MyDrive/Colaboratory/memo.txt', 'a') as f:
    f.write('\n')
    f.writelines(s_score)

# %% [markdown]
# #スコア確かめる用

# %%
print(max_score_list)
print(ai_score_list)
print(score)
# Out:
# [371.3489871838435, 461.1262766612154, 322.8471473579065, 423.9379115492891]
# [360.4365220142282, 446.78868282543846, 321.55173594355944, 413.0000339849077]
# [0.9706139896802441, 0.9689074456142723, 0.9959875395370584, 0.9741993408317536]

# %%
print(max_score_list)
print(ai_score_list)
print(score)
# Out:
# [371.3489871838435, 461.1262766612154, 322.8471473579065]
# [362.80234955824, 456.00714238204625, 321.3366274672457]
# [0.9769848904384588, 0.9888986281236579, 0.995321253717053]

# %% [markdown]
# #Fスコアが一番高い枚数までnewフォルダに移動

# %%
_, ind_i = smax(ice_cream)['F1']
_, ind_n = smax(nigirizushi)['F1']
_, ind_s = smax(spring_roll)['F1']
_, ind_c = smax(carrot)['F1']

# %%
os.mkdir('/content/sample_data/new')
for i in range(4):
    os.mkdir('/content/sample_data/new/' + item[i])

# %%
import imghdr

for file in files:
    if imghdr.what(file) !=  'jpeg':
        print(file)
item = ['ice_cream', 'nigirizushi', 'spring_roll', 'true_carrot']
ind = ['ind_i', 'ind_n', 'ind_s', 'ind_c']
for i in range(4):
    files = glob.glob('/content/sample_data/dataset/' + item[i] + '/*')
    j = 1
    for file in files:
        if j > eval(ind[i]):
            break
        if imghdr.what(file) !=  'jpeg':
            continue
        shutil.copyfile(file, '/content/sample_data/new/' + item[i] + '/' + str(j) + '.jpg')
        j += 1
# Out:
# /content/sample_data/dataset/ice_cream/000187.jpg
# /content/sample_data/dataset/ice_cream/000092.jpg
# /content/sample_data/dataset/ice_cream/000149.jpg
# /content/sample_data/dataset/ice_cream/000139.jpg
# /content/sample_data/dataset/ice_cream/000132.jpg

# %% [markdown]
# #手動によるスコア測定

# %%
nigirizushi_score = []
spring_roll_score = []
carrot_score = []
#now = -1
now = 0
# score_name = ['ice_cream_score', 'nigirizushi_score', 'spring_roll_score']
# path_name = ['ice_cream', 'nigirizushi', 'spring_roll']
score_name = ['carrot_score']
path_name = ['carrot_score']
stack = []
def remove():
    global now
    global score
    rem = eval(score_name[now]).pop()
    p, s = rem
    print(p)
    print(s)
    stack.append(p)
    return enter(stk=stack)

def enter(file='', stk=[]):
    if file != '':
        print(file)
        score = ''
        while 1:
            score = input('enter the score : ')
            if score == '-1':
                break
            if score.isdecimal() and int(score) >= 0 and int(score) <= 10:
                break
        if score == '-1':
            stack.append(file)
            remove()
        else:
            t = (file, score)
            eval(score_name[now]).append(t)
    elif stack != []:
        print(stack[-1])
        score = ''
        while 1:
            score = input('enter the score : ')
            if score == '-1':
                break
            if score.isdecimal() and int(score) >= 0 and int(score) <= 10:
                break           
        if score == '-1':
            remove()
        else:
            path = stack.pop()
            t = (path, score)
            eval(score_name[now]).append(t)  
            enter(stk=stk)   

def score():
    files = glob.glob('/content/sample_data/carrot_score/*')
    files = natsorted(files)
    for file in files:
        global now
        global path_name
        basename = os.path.basename(file)
        name, ext = os.path.splitext(basename)
        dirname = os.path.dirname(file)
        _, dirname = os.path.split(dirname)
        score = enter(file)
#複数用
# def score():
#     dirs = glob.glob('/content/sample_data/dataset/*')
#     for dir in dirs:
#         global now
#         global path_name
#         now += 1
#         files = glob.glob('/content/sample_data/dataset/' + path_name[now] + '/*')
#         files = natsorted(files)
#         for file in files:
#             basename = os.path.basename(file)
#             name, ext = os.path.splitext(basename)
#             dirname = os.path.dirname(file)
#             _, dirname = os.path.split(dirname)
#             if dirname == 'ice_cream':
#                 break
#             score = enter(file)

# %%
score()
# Out:
# /content/sample_data/carrot_score/000001.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000002.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000003.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000004.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000005.jpg
# enter the score : -1
# /content/sample_data/carrot_score/000004.jpg
# 10
# /content/sample_data/carrot_score/000004.jpg
# enter the score : 0
# /content/sample_data/carrot_score/000005.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000006.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000007.jpg
# enter the score : 10
# /content/sample_data/carrot_score/000008.jpg
# enter the score : 0
# /content/sample_data/carrot_score/000009.jpg
# enter the score : 10
# /content/sample_data/carrot_score/
jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/197_617664.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/198_616311.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/199_612538.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/200_610394.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/201_605751.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/202_600265.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/203_595931.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/204_595580.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/205_523530.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/206_492840.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/207_489493.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/208_482186.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/209_436223.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/210_430466.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/211_419907.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/212_419389.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/213_399491.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/214_376811.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/215_345295.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/216_146965.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/217_118938.jpg', '0'),
 ('/content/sample_data/dataset/spring_roll/218_55750.jpg', '0')]

# %% [markdown]
# #renaming in order of score

# %%
a = ['spring_roll_lank', 'nigirizushi_lank', 'ice_cream_lank']
for i in range(3):
    j = 0
    for l in eval(a[i]):
        path, score = l
        dir_name = os.path.dirname(path)
        n = score * 1000000
        n = round(n)
        s = str(j) + '_' + str(int(n))
        new_path = os.path.join(dir_name, str(s) + '.jpg')
        os.rename(path, new_path)
        j += 1

# %% [markdown]
# #One code below is enough to put it all together
# differentとimproperを選んで移動

# %%
import shutil
image_paths = glob.glob('/content/sample_data/sample_food/*/*.jpg')

i = 0
for image_path in image_paths:
    dir_name = os.path.dirname(image_path)
    _, dir_name = os.path.split(dir_name)
    dir_path = os.path.dirname(image_path)

    if dir_name == 'different_images' or dir_name == 'improper_images':
        break
    image = Image.open(image_path).convert('RGB')
    im = image
    image = preprocess_image(image)
    image = tf.image.resize(image, [CROP_TO, CROP_TO])

    logits = saved_module(image)
    image = image[0]


    if len(logits.shape) > 1:
        logits = tf.reshape(logits, [-1])

    correct_label = food_labels.index(dir_name)

    MAX_PREDS = 5
    MIN_SCORE = 0.8
    MAX_SCORE = 0.0
    MAX_LABEL = None
    classes = []
    scores = []
    CORRECT_SCORE = 0.0
    # Do not show labels with lower score than this:
    print(image_path)
    for index, j in enumerate(np.argsort(logits)[-MAX_PREDS::][::-1]):
        score = 1.0/(1.0 + np.exp(-logits[j]))
        print(j, end='   :   ')
        print(score)
        if j == correct_label:
            CORRECT_SCORE = score
        if score > MAX_SCORE:
            MAX_SCORE = score
            MAX_LABEL = j

    if MAX_SCORE < MIN_SCORE or CORRECT_SCORE < MIN_SCORE:
        display(im)
        # new_path = os.path.join(dir_path, dir_name + os.path.basename(image_path))
        # os.rename(image_path, new_path)
        # shutil.move(new_path, '/content/sample_data/dataset/improper_images')
        print(image_path)
        print(MAX_SCORE)
        print('---------------')

    if correct_label != MAX_LABEL:
        display(im)
        # name = os.path.dirname(image_path)
        # _, name = os.path.split(name)
        # name += '_to_'
        # name += food_labels[MAX_LABEL]
        # sample_path = os.path.join(dir_path, name)
        print(image_path)
        # print(name)
        # print(dir_path)
        # print(sample_path)
        # try:
        #     os.rename(image_path, sample_path)
        #     shutil.copyfile(sample_path, os.path.join('/content/sample_data/dataset/different_images', name))
        #     new_path = os.path.join(dir_path, dir_name + os.path.basename(image_path))
        #     os.rename(sample_path, new_path)
        #     print(new_path)
        #     correct_name = food_labels[MAX_LABEL]
        #     dd_path, _ = os.path.split(dir_path)
        #     next_path = os.path.join(dd_path, correct_name)
        #     new_next_path = os.path.join(next_path, os.path.basename(new_path))
        #     print(new_next_path)
            # shutil.copyfile(new_path, new_next_path)

        # except FileNotFoundError as e:
        #     pass


    MAX_SCORE = 0
    if i % 2 == 0:
        print(food_labels)
    print("------------")
    i += 1

# %% [markdown]
# #zip the dataset and download it localy

# %%
os.chdir('/content/sample_data/dataset')
# Out:
# 2021-02-05 06:57:04,704 - INFO - parser - parser-001 is waiting for new page urls

# %%
# !zip true_dataset3.zip ./*/*

# %%
from google.colab import files
files.download('carrot.zip')
# Out:
# 2021-02-05 06:45:23,394 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:45:33,278 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:45:47,286 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:46:10,287 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:46:18,293 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:46:51,447 - INFO - parser - parser-001 is waiting for new page urls
# 2021-02-05 06:47:09,458 - INFO - parser - parser-001 is waiting for new page urls

# %% [markdown]
# #print the ds_train

# %%
for features in ds_train.take(20):
  image = features['image']
  image = preprocess_image(image)
  image = tf.image.resize(image, [CROP_TO, CROP_TO])

  logits = saved_module(image)

  show_preds(logits, image[0], correct_food_label=features['label'].numpy(), tf_food_logits=True)

# %% [markdown]
# #For practice

# %%
for i in range(3):
    shutil.rmtree('/content/sample_data/' + name[i])

# %%
try:
    shutil.rmtree('/content/sample_data/dataset')
except:
    pass
os.mkdir('/content/sample_data/true_dataset2')
os.chdir('/content/sample_data/true_dataset2')
shutil.copyfile('/content/drive/MyDrive/Colaboratory/dataset/true_dataset2.zip', '/content/sample_data/dataset.zip')
# !unzip /content/sample_data/dataset
os.rename('/content/sample_data/true_dataset2', '/content/sample_data/dataset')
# Out:
# Archive:  /content/sample_data/dataset.zip
#   inflating: ice_cream/000001.jpg
#   inflating: ice_cream/000002.jpg
#   inflating: ice_cream/000003.jpg
#   inflating: ice_cream/000004.jpg
#   inflating: ice_cream/000005.jpg
#   inflating: ice_cream/000006.jpg
#   inflating: ice_cream/000007.jpg
#   inflating: ice_cream/000008.jpg
#   inflating: ice_cream/000009.jpg
#   inflating: ice_cream/000010.jpg
#   inflating: ice_cream/000011.jpg
#   inflating: ice_cream/000012.jpg
#   inflating: ice_cream/000013.jpg
#   inflating: ice_cream/000014.jpg
#   inflating: ice_cream/000015.jpg
#   inflating: ice_cream/000016.jpg
#   inflating: ice_cream/000017.jpg
#   inflating: ice_cream/000018.jpg
#   inflating: ice_cream/000019.jpg
#   inflating: ice_cream/000020.jpg
#   inflating: ice_cream/000021.jpg
#   inflating: ice_cream/000022.jpg
#   inflating: ice_cream/000023.jpg
#   inflating: ice_cream/000024.jpg
#   inflating: ice_cream/000025.jpg
#   inflating: ice_cream/000026.jpg
# ...

# %%
ice_cream

# %%
os.chdir('../')
shutil.rmtree('./tashikame')
os.mkdir('/content/tashikame')
os.chdir('/content/tashikame')

# %%
dl('spring roll', 'spring_roll')

# %%
# !zip tashikame.zip ./*/*
from google.colab import files
files.download('tashikame.zip')
